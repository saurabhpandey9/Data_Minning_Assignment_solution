# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets, linear_model
from sklearn.model_selection import train_test_split
import random
import statistics

# %%
df = pd.read_csv('car.csv')

# %%
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]
df.head()
# Out:
#                          Car   MPG  Cylinders  ...  Acceleration  Model  Origin
# 0  Chevrolet Chevelle Malibu  18.0          8  ...          12.0     70      US
# 1          Buick Skylark 320  15.0          8  ...          11.5     70      US
# 2         Plymouth Satellite  18.0          8  ...          11.0     70      US
# 3              AMC Rebel SST  16.0          8  ...          12.0     70      US
# 4                Ford Torino  17.0          8  ...          10.5     70      US
#
# [5 rows x 9 columns]

# %%
df2 = df
df2 = df2.drop(['Origin'],axis='columns')
df2 = df2.drop(['Car'],axis='columns')
df3= df2

# %%
# Max-min normalisation  value between 0-1
df2=(df2-df2.min())/(df2.max()-df2.min())

# %%
df2.describe()
# Out:
#               MPG   Cylinders  ...  Acceleration       Model
# count  406.000000  406.000000  ...    406.000000  406.000000
# mean     0.494662    0.495074  ...      0.447601    0.493432
# std      0.180296    0.342432  ...      0.166867    0.312395
# min      0.000000    0.000000  ...      0.000000    0.000000
# 25%      0.364807    0.200000  ...      0.339286    0.250000
# 50%      0.479614    0.200000  ...      0.446429    0.500000
# 75%      0.622318    1.000000  ...      0.546131    0.750000
# max      1.000000    1.000000  ...      1.000000    1.000000
#
# [8 rows x 7 columns]

# %%
df.describe()
# Out:
#               MPG   Cylinders  ...  Acceleration       Model
# count  406.000000  406.000000  ...    406.000000  406.000000
# mean    23.051232    5.475369  ...     15.519704   75.921182
# std      8.401777    1.712160  ...      2.803359    3.748737
# min      0.000000    3.000000  ...      8.000000   70.000000
# 25%     17.000000    4.000000  ...     13.700000   73.000000
# 50%     22.350000    4.000000  ...     15.500000   76.000000
# 75%     29.000000    8.000000  ...     17.175000   79.000000
# max     46.600000    8.000000  ...     24.800000   82.000000
#
# [8 rows x 7 columns]

# %%
# z score normalisation
df3 = (df3 - df3.mean())/df3.std()
df3
# Out:
#           MPG  Cylinders  Displacement  ...    Weight  Acceleration     Model
# 0   -0.601210   1.474530      1.069556  ...  0.619343     -1.255531 -1.579514
# 1   -0.958277   1.474530      1.479382  ...  0.842482     -1.433889 -1.579514
# 2   -0.601210   1.474530      1.174395  ...  0.539060     -1.612246 -1.579514
# 3   -0.839255   1.474530      1.040963  ...  0.535518     -1.255531 -1.579514
# 4   -0.720232   1.474530      1.021902  ...  0.554408     -1.790604 -1.579514
# 5   -0.958277   1.474530      2.232319  ...  1.607532     -1.968961 -1.579514
# 6   -1.077300   1.474530      2.470591  ...  1.622880     -2.325676 -1.579514
# 7   -1.077300   1.474530      2.337159  ...  1.573293     -2.504034 -1.579514
# 8   -1.077300   1.474530      2.480121  ...  1.706705     -1.968961 -1.579514
# 9   -0.958277   1.474530      1.860616  ...  1.027842     -2.504034 -1.579514
# 10  -2.743614  -0.861701     -0.588812  ...  0.130562      0.706401 -1.579514
# ...

# %%
# since df2 was already min-max normalised, we just needed direct displacement
df2 = df2 * 20 + 10

# %%
df2
# Out:
#            MPG  Cylinders  Displacement  ...     Weight  Acceleration  Model
# 0    17.725322       30.0     22.351421  ...  20.722994     14.761905   10.0
# 1    16.437768       30.0     24.573643  ...  21.794726     14.166667   10.0
# 2    17.725322       30.0     22.919897  ...  20.337397     13.571429   10.0
# 3    16.866953       30.0     22.196382  ...  20.320386     14.761905   10.0
# 4    17.296137       30.0     22.093023  ...  20.411114     12.976190   10.0
# 5    16.437768       30.0     28.656331  ...  25.469237     12.380952   10.0
# 6    16.008584       30.0     29.948320  ...  25.542954     11.190476   10.0
# 7    16.008584       30.0     29.224806  ...  25.304792     10.595238   10.0
# 8    16.008584       30.0     30.000000  ...  25.945563     12.380952   10.0
# 9    16.437768       30.0     26.640827  ...  22.685001     10.595238   10.0
# 10   10.000000       14.0     13.359173  ...  18.375390     21.309524   10.0
# ...

# %% [markdown]
# # Part-B

# %%
df = pd.read_csv("p2.csv")

# %%
df.count()
# Out:
# name       20
# country    20
# salary     20
# age        20
# smoking    20
# dtype: int64

# %%
statistics.stdev(df['country'])
# Out:
# 1.1002392084403616

# %%
df.dtypes
# Out:
# name       object
# country     int64
# salary      int64
# age         int64
# smoking    object
# dtype: object

# %%
df['country'].describe()
# Out:
# count    20.000000
# mean      2.500000
# std       1.100239
# min       1.000000
# 25%       2.000000
# 50%       2.000000
# 75%       3.250000
# max       4.000000
# Name: country, dtype: float64

# %%
df
# Out:
#        name   country  salary  age smoking
# 0   Himanshu        1      70   20      No
# 1      Ayush        2      90   21     Yes
# 2    Prahlad        3      80   22     Yes
# 3      Bhuvi        4      70   31     Yes
# 4   Kavyansh        3      50   34      No
# 5     Akella        4      90   12      No
# 6   Amardeep        2      80   23      No
# 7     Ankush        1     100   21      No
# 8    Rajnish        2      67   20      No
# 9       Anuj        2      46   19     Yes
# 10    Hitesh        4      35   18     Yes
# 11     Rohit        3      75   12     Yes
# 12       Jai        1      35   12      No
# 13    Ritwik        4      87   31      No
# 14    Anurag        4      46   12     Yes
# 15   Utkarsh        2      24   43      No
# 16     Vivek        1      40   23     Yes
# 17      Yash        2      37   22      No
# 18     Heera        3      84   21      No
# 19  Abhishek        2      66   32     Yes

# %%
statistics.mean(df['country'])
# Out:
# 2.5

# %%
df['country'].value_counts()
# Out:
# 2    7
# 4    5
# 3    4
# 1    4
# Name: country, dtype: int64

# %%
df[df.smoking=='Yes'].groupby('smoking').size() # people who smoke
# Out:
# smoking
# Yes    9
# dtype: int64

# %%
df.dtypes
# Out:
# name       object
# country     int64
# salary      int64
# age         int64
# smoking    object
# dtype: object

# %%
df['country'] = df.country.astype('category')
df['smoking'] = df.smoking.astype('category')

# %%
statistics.mean(df['country'])
# Out:
# 2.5

# %%
df['country'].describe()
# Out:
# count     20
# unique     4
# top        2
# freq       7
# Name: country, dtype: int64

# %%
df.dtypes
# Out:
# name         object
# country    category
# salary        int64
# age           int64
# smoking    category
# dtype: object

# %%
statistics.stdev(df['country'])
# Out:
# 1.1002392084403616

# %%
df['country'].describe()
# Out:
# count     20
# unique     4
# top        2
# freq       7
# Name: country, dtype: int64

# %%
df['country'].value_counts()
# Out:
# 2    7
# 4    5
# 3    4
# 1    4
# Name: country, dtype: int64

# %%
sum()

# %%
df[df.smoking=='Yes'].groupby('smoking',).size()
# Out:
# smoking
# No     0
# Yes    9
# dtype: int64

# %%
df
# Out:
#        name  country  salary  age smoking
# 0   Himanshu       1      70   20      No
# 1      Ayush       2      90   21     Yes
# 2    Prahlad       3      80   22     Yes
# 3      Bhuvi       4      70   31     Yes
# 4   Kavyansh       3      50   34      No
# 5     Akella       4      90   12      No
# 6   Amardeep       2      80   23      No
# 7     Ankush       1     100   21      No
# 8    Rajnish       2      67   20      No
# 9       Anuj       2      46   19     Yes
# 10    Hitesh       4      35   18     Yes
# 11     Rohit       3      75   12     Yes
# 12       Jai       1      35   12      No
# 13    Ritwik       4      87   31      No
# 14    Anurag       4      46   12     Yes
# 15   Utkarsh       2      24   43      No
# 16     Vivek       1      40   23     Yes
# 17      Yash       2      37   22      No
# 18     Heera       3      84   21      No
# 19  Abhishek       2      66   32     Yes

# %%
df.describe()
# Out:
#              salary           age
# count  2.000000e+01  2.000000e+01
# mean  -3.122502e-17  6.661338e-17
# std    1.000000e+00  1.000000e+00
# min   -1.750557e+00 -1.272703e+00
# 25%   -8.443344e-01 -4.506220e-01
# 50%    2.166094e-01 -1.765951e-01
# 75%    7.691842e-01  3.105638e-01
# max    1.609098e+00  2.502779e+00

# %%
df.salary = (df.salary-mean_sal)/std_sal
df.age= (df.age-mean_age)/std_age

# %%
df
# Out:
#        name  country    salary       age smoking
# 0   Himanshu       1 -2.798994 -2.770520      No
# 1      Ayush       2 -2.759911 -2.755687     Yes
# 2    Prahlad       3 -2.779453 -2.740854     Yes
# 3      Bhuvi       4 -2.798994 -2.607360     Yes
# 4   Kavyansh       3 -2.838078 -2.562862      No
# 5     Akella       4 -2.759911 -2.889182      No
# 6   Amardeep       2 -2.779453 -2.726022      No
# 7     Ankush       1 -2.740369 -2.755687      No
# 8    Rajnish       2 -2.804857 -2.770520      No
# 9       Anuj       2 -2.845894 -2.785353     Yes
# 10    Hitesh       4 -2.867390 -2.800185     Yes
# 11     Rohit       3 -2.789223 -2.889182     Yes
# 12       Jai       1 -2.867390 -2.889182      No
# 13    Ritwik       4 -2.765773 -2.607360      No
# 14    Anurag       4 -2.845894 -2.889182     Yes
# 15   Utkarsh       2 -2.888886 -2.429367      No
# 16     Vivek       1 -2.857619 -2.726022     Yes
# 17      Yash       2 -2.863482 -2.740854      No
# ...

# %%
df[['salary','age']]
# Out:
#       salary       age
# 0  -2.798994 -2.770520
# 1  -2.759911 -2.755687
# 2  -2.779453 -2.740854
# 3  -2.798994 -2.607360
# 4  -2.838078 -2.562862
# 5  -2.759911 -2.889182
# 6  -2.779453 -2.726022
# 7  -2.740369 -2.755687
# 8  -2.804857 -2.770520
# 9  -2.845894 -2.785353
# 10 -2.867390 -2.800185
# 11 -2.789223 -2.889182
# 12 -2.867390 -2.889182
# 13 -2.765773 -2.607360
# 14 -2.845894 -2.889182
# 15 -2.888886 -2.429367
# 16 -2.857619 -2.726022
# 17 -2.863482 -2.740854
# 18 -2.771636 -2.755687
# 19 -2.806811 -2.592527

# %%
df['age'].mean()
# Out:
# -2.7341797142015936

# %%
df[df.age>d6]
# Out:
#        name  country    salary       age smoking
# 3      Bhuvi       4 -2.798994 -2.607360     Yes
# 4   Kavyansh       3 -2.838078 -2.562862      No
# 6   Amardeep       2 -2.779453 -2.726022      No
# 13    Ritwik       4 -2.765773 -2.607360      No
# 15   Utkarsh       2 -2.888886 -2.429367      No
# 16     Vivek       1 -2.857619 -2.726022     Yes
# 19  Abhishek       2 -2.806811 -2.592527     Yes
